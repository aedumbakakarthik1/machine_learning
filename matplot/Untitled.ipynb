# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("13.1 heart-disease.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot();

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df["age"].plot(kind="hist");

# %%
df.plot.hist(subplots=True);

# %%
df.plot.hist(subplots=True,figsize=(10,30));

# %%
over_50 =df[ df["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
over_50.plot(kind="scatter",x="age",y="chol",c="target");

# %%
#oo method mixed with pyplot method
fix,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter"
            ,x="age",
            y="chol",
            c="target",
            ax=ax);
ax.set_xlim([50,67])
# Out:
# (50.0, 67.0)

# %%
# oo method from scratch
fx, ax= plt.subplots(figsize=(10,6))

#ploting the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

# customize plotting 
ax.set(title="heart disease and cholesterol  levels",
      xlabel="age",
      ylabel="Cholesterol")
# adding the legned
ax.legend(*scatter.legend_elements(),title="Target");

# adding a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--",c="green");

#adding  a  vertical line
ax.axvline(over_50["age"].mean(),linestyle="--",c="red");

# %%
#subplot of chol , age, thalach
# for chol and age 
fig, (ax1,ax2)= plt.subplots(nrows=2,
                            ncols=1,figsize=(10,6),sharex=True)
#scatter the plot
scatter=ax1.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"]
                   )
ax1.set(title="heart disease and cholesterol  levels",
#       xlabel="age",
      ylabel="Cholesterol");
# adding the legned
ax1.legend(*scatter.legend_elements(),title="Target");

# adding a horizontal line
ax1.axhline(over_50["chol"].mean(),linestyle="--",c="green");



# for age and thalach
scatter = ax2.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])


ax2.set(title="heart disease  with age and thalach",
       xlabel="Age",
       ylabel="thalach");

# adding legned
ax2.legend(*scatter.legend_elements(),title="Target");

# adding horizontal line
ax2.axhline(over_50["thalach"].mean(),linestyle="--");


# add a title for fig

fig.suptitle("Heart Disease Analysis", fontsize=16,fontweight="bold");

# %%
#customizing Matplot plot and getting stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
df["age"].plot();

# %%
plt.style.use("dark_background")

# %%
df["age"].plot();

# %%
#set the style
plt.style.use("seaborn-whitegrid")

# oo method from scratch
fig, ax= plt.subplots(figsize=(10,6))

#ploting the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="plasma") #  this will changes the colour scheme

# customize plotting 
ax.set(title="heart disease and cholesterol  levels",
      xlabel="age",
      ylabel="Cholesterol")
# adding the legned
ax.legend(*scatter.legend_elements(),title="Target");

# adding a horizontal line
ax.axhline(over_50["chol"].mean(),linestyle="--",c="green");

#adding  a  vertical line
ax.axvline(over_50["age"].mean(),linestyle="--",c="red");

# %%
#set the style
plt.style.use("seaborn-whitegrid")

#subplot of chol , age, thalach
# for chol and age 
fig, (ax1,ax2)= plt.subplots(nrows=2,
                            ncols=1,figsize=(10,6),sharex=True)
#scatter the plot
scatter=ax1.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"],
                    cmap="plasma"
                   )
ax1.set(title="heart disease and cholesterol  levels",
#       xlabel="age",
      ylabel="Cholesterol");
# adding the legned
ax1.legend(*scatter.legend_elements(),title="Target");

# adding a horizontal line
ax1.axhline(over_50["chol"].mean(),linestyle="--",c="green");



# for age and thalach
scatter = ax2.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter")


ax2.set(title="heart disease  with age and thalach",
       xlabel="Age",
       ylabel="thalach");

# adding legned
ax2.legend(*scatter.legend_elements(),title="Target");

# adding horizontal line
ax2.axhline(over_50["thalach"].mean(),linestyle="--");


# add a title for fig

fig.suptitle("Heart Disease Analysis", fontsize=16,fontweight="bold");
